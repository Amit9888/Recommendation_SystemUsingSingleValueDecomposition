# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('AmazonRating.csv')
df.shape
# Out:
# (4848, 207)

# %%
###We will first do some exporatory data anlaysis on the data

# %%
df.head()
# Out:
#           user_id  Movie1  Movie2  Movie3  Movie4  Movie5  Movie6  Movie7  \
# 0  A3R5OBKS7OM2IR     5.0     5.0     NaN     NaN     NaN     NaN     NaN
# 1   AH3QC2PC1VTGP     NaN     NaN     2.0     NaN     NaN     NaN     NaN
# 2  A3LKP6WPMP9UKX     NaN     NaN     NaN     5.0     NaN     NaN     NaN
# 3   AVIY68KEPQ5ZD     NaN     NaN     NaN     5.0     NaN     NaN     NaN
# 4  A1CV1WROP5KTTW     NaN     NaN     NaN     NaN     5.0     NaN     NaN
#
#    Movie8  Movie9  ...  Movie197  Movie198  Movie199  Movie200  Movie201  \
# 0     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 1     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 2     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 3     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 4     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
#
#    Movie202  Movie203  Movie204  Movie205  Movie206
# ...

# %%
mean_columns={}

# %%
df.columns
# Out:
# Index(['user_id', 'Movie1', 'Movie2', 'Movie3', 'Movie4', 'Movie5', 'Movie6',
#        'Movie7', 'Movie8', 'Movie9',
#        ...
#        'Movie197', 'Movie198', 'Movie199', 'Movie200', 'Movie201', 'Movie202',
#        'Movie203', 'Movie204', 'Movie205', 'Movie206'],
#       dtype='object', length=207)

# %%
#What is the average rating for each movie? Define the top 5 movies with the maximum ratings.


df.mean().sort_values(ascending=False).head(5)
# Out:
# Movie1      5.0
# Movie55     5.0
# Movie131    5.0
# Movie132    5.0
# Movie133    5.0
# dtype: float64

# %%
# Which movies have maximum views/ratings?

# %%
# for  this we will have to calculate the amount of the null values in every column 
#and then select column with the least amount of null values

# %%
value_counts={}

# %%
for i in df.columns:
    value_counts[i]=df[i].isnull().sum()

# %%
 sorted(value_counts.items(), key =  lambda kv:(kv[1], kv[0]))
# Out:
# [('user_id', 0),
#  ('Movie127', 2535),
#  ('Movie140', 4270),
#  ('Movie16', 4528),
#  ('Movie103', 4576),
#  ('Movie29', 4605),
#  ('Movie91', 4720),
#  ('Movie92', 4747),
#  ('Movie89', 4765),
#  ('Movie158', 4782),
#  ('Movie108', 4794),
#  ('Movie107', 4809),
#  ('Movie111', 4809),
#  ('Movie205', 4813),
#  ('Movie182', 4818),
#  ('Movie5', 4819),
#  ('Movie161', 4823),
#  ('Movie185', 4824),
#  ('Movie86', 4827),
#  ('Movie90', 4830),
#  ('Movie184', 4831),
#  ('Movie52', 4831),
#  ('Movie162', 4833),
#  ('Movie173', 4833),
#  ('Movie109', 4835),
#  ('Movie138', 4835),
#  ('Movie163', 4835),
#  ('Movie206', 4835),
#  ('Movie81', 4836),
#  ('Movie117', 4837),
#  ('Movie192', 4838),
#  ('Movie186', 4839),
#  ('Movie196', 4839),
#  ('Movie110', 4840),
#  ('Movie119', 4840),
#  ('Movie200', 4840),
#  ('Movie204', 4840),
#  ('Movie114', 4841),
#  ('Movie141', 4841),
#  ('Movie179', 4841),
#  ('Movie190', 4841),
#  ('Movie193', 4841),
#  ('Movie194', 4841),
#  ('Movie43', 4841),
# ...

# %%
# Which movies have maximum views/ratings?

# %%
# for  this we will have to calculate the amount of the null values in every column 
#and then select column with the least amount of null values

# %%
#The movies with maximum ratings/views are 
#Movie127' 
#Movie140'
#Movie16' 
#Movie103'
#Movie29' 
#Movie91' 
#Movie92' 
#Movie89'

# %%
# Define the top 5 movies with the least audience.

# %%
sorted(value_counts.items(), key =  lambda kv:(kv[0], kv[1]))

# %%
# Define the top 5 movies with the least audience.
#'Movie1', 
#'Movie10',
#'Movie100', 
#'Movie101'
#'Movie102'
#'Movie103'
#'Movie104'
#'Movie105'

# %%
##Now as your dataset has  over 200 variables/independent features we must now do some thing about it!!
#WE will do the principal component analysis on the dataset

# %%
from sklearn.decomposition  import PCA

# %%
pca=PCA(n_components=8)

# %%
df_copy=df.copy()

# %%
df.head()
# Out:
#           user_id  Movie1  Movie2  Movie3  Movie4  Movie5  Movie6  Movie7  \
# 0  A3R5OBKS7OM2IR     5.0     5.0     NaN     NaN     NaN     NaN     NaN
# 1   AH3QC2PC1VTGP     NaN     NaN     2.0     NaN     NaN     NaN     NaN
# 2  A3LKP6WPMP9UKX     NaN     NaN     NaN     5.0     NaN     NaN     NaN
# 3   AVIY68KEPQ5ZD     NaN     NaN     NaN     5.0     NaN     NaN     NaN
# 4  A1CV1WROP5KTTW     NaN     NaN     NaN     NaN     5.0     NaN     NaN
#
#    Movie8  Movie9  ...  Movie197  Movie198  Movie199  Movie200  Movie201  \
# 0     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 1     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 2     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 3     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 4     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
#
#    Movie202  Movie203  Movie204  Movie205  Movie206
# ...

# %%
df_copy.drop('user_id',axis=1,inplace=True)

# %%
len(df_copy[df_copy.Movie10 == 0])
# Out:
# 0

# %%
temp=[]

# %%
for col in df_copy.columns:
    
    temp.append(len(df_copy[df_copy[col] == 0]))

# %%
# pca.fit(df_copy)

# %%
#We will fill the missing values with the zer0

# %%
df_copy.fillna()

# %%
df_copy.fillna(0,inplace=True)

# %%
temp=[]

# %%
pca.fit(df_copy)
# Out:
# PCA(n_components=8)

# %%
pca_data=pca.transform(df_copy)

# %%
pca_data.shape
# Out:
# (4848, 8)

# %%
df_copy.iloc[:,0:8].columns
# Out:
# Index(['Movie1', 'Movie2', 'Movie3', 'Movie4', 'Movie5', 'Movie6', 'Movie7',
#        'Movie8'],
#       dtype='object')

# %%
pca_df=pd.DataFrame(pca_data,columns=df_copy.iloc[:,0:8].columns)

# %%
pca_df
# Out:
#         Movie1    Movie2    Movie3    Movie4    Movie5    Movie6    Movie7  \
# 0     1.575726 -0.793057 -0.167303  0.090578 -0.798161 -0.524948 -0.297458
# 1     1.573112 -0.789827 -0.166105  0.089865 -0.788884 -0.515380 -0.291298
# 2     1.575726 -0.793057 -0.167303  0.090578 -0.798161 -0.524948 -0.297458
# 3     1.575726 -0.793057 -0.167303  0.090578 -0.798161 -0.524948 -0.297458
# 4     1.607312 -0.833262 -0.182804  0.099886 -0.925573 -0.669443 -0.394108
# ...        ...       ...       ...       ...       ...       ...       ...
# 4843  1.591242 -0.812554 -0.174691  0.094996 -0.857263 -0.589010 -0.339509
# 4844  1.591242 -0.812554 -0.174691  0.094996 -0.857263 -0.589010 -0.339509
# 4845  1.591242 -0.812554 -0.174691  0.094996 -0.857263 -0.589010 -0.339509
# 4846  1.591242 -0.812554 -0.174691  0.094996 -0.857263 -0.589010 -0.339509
# 4847  1.591242 -0.812554 -0.174691  0.094996 -0.857263 -0.589010 -0.339509
#
#         Movie8
# 0    -0.065563
# 1    -0.063771
# 2    -0.065563
# ...

# %%
from surprise import Reader
from surprise import accuracy
from surprise.model_selection import train_test_split

# %%
df
# Out:
#              user_id  Movie1  Movie2  Movie3  Movie4  Movie5  Movie6  Movie7  \
# 0     A3R5OBKS7OM2IR     5.0     5.0     NaN     NaN     NaN     NaN     NaN
# 1      AH3QC2PC1VTGP     NaN     NaN     2.0     NaN     NaN     NaN     NaN
# 2     A3LKP6WPMP9UKX     NaN     NaN     NaN     5.0     NaN     NaN     NaN
# 3      AVIY68KEPQ5ZD     NaN     NaN     NaN     5.0     NaN     NaN     NaN
# 4     A1CV1WROP5KTTW     NaN     NaN     NaN     NaN     5.0     NaN     NaN
# ...              ...     ...     ...     ...     ...     ...     ...     ...
# 4843  A1IMQ9WMFYKWH5     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4844  A1KLIKPUF5E88I     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4845   A5HG6WFZLO10D     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4846  A3UU690TWXCG1X     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4847   AI4J762YI6S06     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# ...

# %%
melt_df = df.melt(id_vars = df.columns[0], value_vars= df.columns[1:], var_name="movie_name", value_name="rating")
melt_df
# Out:
#                user_id movie_name  rating
# 0       A3R5OBKS7OM2IR     Movie1     5.0
# 1        AH3QC2PC1VTGP     Movie1     NaN
# 2       A3LKP6WPMP9UKX     Movie1     NaN
# 3        AVIY68KEPQ5ZD     Movie1     NaN
# 4       A1CV1WROP5KTTW     Movie1     NaN
# ...                ...        ...     ...
# 998683  A1IMQ9WMFYKWH5   Movie206     5.0
# 998684  A1KLIKPUF5E88I   Movie206     5.0
# 998685   A5HG6WFZLO10D   Movie206     5.0
# 998686  A3UU690TWXCG1X   Movie206     5.0
# 998687   AI4J762YI6S06   Movie206     5.0
#
# [998688 rows x 3 columns]

# %%
from surprise import Dataset
reader = Reader(rating_scale=(-1,10))
data = Dataset.load_from_df(melt_df.fillna(0), reader=reader)

# %%
trainset, testset = train_test_split(data, test_size=0.25)

# %%
from surprise import SVD

# %%
data

# %%
algorithmm = SVD()

# %%
algorithmm.fit(trainset)
